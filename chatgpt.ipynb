# %%
import http.client
import json
ask=input('What would you like to ask me?')

conn = http.client.HTTPSConnection("chatgpt-42.p.rapidapi.com")

payload = "{\"messages\":[{\"role\":\"user\",\"content\":\""+ask+"\"}],\"web_access\":false}"

headers = {
    'x-rapidapi-key': "722fb68cc9msh33b64b45b6aa207p126ba5jsn9f1eff4986ae",
    'x-rapidapi-host': "chatgpt-42.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("POST", "/chatgpt", payload, headers)

res = conn.getresponse()
data = res.read()

mydata=json.loads(data.decode("utf-8"))
print(mydata['result'])
# Out:
# What would you like to ask me? esc
# Hey Marwa, what’s up?
